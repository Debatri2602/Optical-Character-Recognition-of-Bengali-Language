# %% [markdown]
# # Bengali Optical Character Recognition

# %%
# import libraries
import pytesseract
import cv2
import os
import matplotlib.pyplot as plt

# %%
# configuration for bengali recognition
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
# getting file names
filenames = os.listdir('C:/Program Files/Tesseract-OCR/tessdata/')
print(filenames)
# Out:
# ['ben.traineddata', 'Bengali.traineddata', 'configs', 'eng.traineddata', 'eng.user-patterns', 'eng.user-words', 'jaxb-api-2.3.1.jar', 'osd.traineddata', 'pdf.ttf', 'piccolo2d-core-3.0.1.jar', 'piccolo2d-extras-3.0.1.jar', 'script', 'ScrollView.jar', 'tessconfigs']

# %%
# reading image
img = cv2.imread('bengali song image.png')

# %%
# showing image
plt.imshow(img)

# %%
# importing libraries
from PIL import Image    
import pytesseract as tess

# %%
# converting image to string
img2char = tess.image_to_string(Image.open('bengali song image.png'), lang='ben')

# %%
print(img2char)
# Out:
# রবীন্দ্রনাথ ঠাকুর
#
# ভালোবেসে সখী নিভৃতে যতনে
# আমার নামটি লিখো তোমার মনের মন্দিরে,
# ভালোবেসে সখী নিভৃতে যতনে
# আমার নামটি লিখো তোমার মনের মন্দিরে.
#
#
#
#
#
# আমার পরানে যে গান বাজিছে
#
# তাহার তালটি শিখো তোমার চরণমঞ্জীরে,
# ভালোবেসে সখী নিভৃতে যতনে
#
# আমার নামটি লিখো তোমার মনের মন্দিরে.
#
#
#
# ধরিয়া রাখিয়ো সোহাগে আদরে
#
#
#
#
#
#
#
#
#
# আমার হাতের রাখী তোমার কনককঙ্কণে..
#
# ভালোবেসে সখী নিভৃতে যতনে
# আমার নামটি লিখো তোমার মনের মন্দিরে,
